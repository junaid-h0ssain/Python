# %%
import glob
images = glob.glob('sample_data/*.jpg')

# %% [markdown]
# # loading the images

# %%
N = len(images)
print(f"Il y a {N} images :")
for f in images:
    print(f)
# Out:
# Il y a 5 images :
# sample_data/01.jpg
# sample_data/02.jpg
# sample_data/05.jpg
# sample_data/04.jpg
# sample_data/03.jpg

# %% [markdown]
# # drawing plot area for each image

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1,N)
plt.show()

# %% [markdown]
# # displaying all images

# %%
import skimage.io as io
import matplotlib.pyplot as plt

# Figure with 1 row, N columns, and a specific size
fig, axs = plt.subplots(1,N, figsize=(15,5))

# Counter for the axes
i = 0

# Loop over the images
for f in images:

    # Load the image
    img = io.imread(f)

    # Display the image in the axe i
    axs[i].imshow(img)

    # Add a title with the filename
    axs[i].set_title(f)

    # Increment the counter
    i = i + 1

# Finally, show the figure
plt.show()

# %%
i=0
for f in images:
    img = io.imread(f)
    axs[i].imshow(img)
    axs[i].set_title(f)
    i = i + 1

    print(img.shape)
# Out:
# (2592, 4608, 3)
# (1436, 1600, 3)
# (1271, 1920, 3)
# (862, 1024, 3)
# (316, 474, 3)

# %%
import skimage.color as color

fig, axs = plt.subplots(1,N, figsize=(15,5))
i=0
for f in images:
  img = io.imread(f)
  img = color.rgb2gray(img)
  axs[i].imshow(img)
  axs[i].set_title(f)
  i = i + 1
plt.show()

# %% [markdown]
# # converting images into greyscale

# %%
fig, axs = plt.subplots(1,N, figsize=(15,5))
i=0
for f in images:
  img = io.imread(f)
  img = color.rgb2gray(img)
  axs[i].imshow(img, cmap="gray")
  axs[i].set_title(f)
  i = i + 1
plt.show()

# %% [markdown]
# # measuring maximum and minimum greyscale value for each image

# %%
i=0
for f in images:
  img = io.imread(f)
  img = color.rgb2gray(img)
  axs[i].imshow(img, cmap="gray")
  axs[i].set_title(f)
  print(axs[i].get_title())
  i = i + 1
  print(f"Min : {img.min()}")
  print(f"Max : {img.max()}\n")
# Out:
# sample_data/01.jpg
# Min : 0.045388627450980386
# Max : 1.0
#
# sample_data/02.jpg
# Min : 0.003370980392156863
# Max : 1.0
#
# sample_data/05.jpg
# Min : 0.04655450980392157
# Max : 0.9980505882352941
#
# sample_data/04.jpg
# Min : 0.0
# Max : 0.9796874509803922
#
# sample_data/03.jpg
# Min : 0.025833333333333333
# Max : 0.9906913725490196

# %% [markdown]
# # testing with limiting greyscale value

# %%
for f in images:
  img = io.imread(f)
  img = color.rgb2gray(img)
  print(img[0,:])
  print('\n')
# Out:
# [0.29999961 0.32352902 0.33501098 ... 0.58574706 0.57595451 0.56026824]
#
#
# [0.6320549  0.6320549  0.63148941 ... 0.61844392 0.62236549 0.62236549]
#
#
# [0.06586471 0.06586471 0.06586471 ... 0.1868851  0.1868851  0.1868851 ]
#
#
# [0.54365529 0.5049902  0.50187922 ... 0.23742157 0.17719059 0.19934392]
#
#
# [0.21627608 0.21459451 0.21851608 0.22130667 0.22353176 0.21847922
#  0.22379255 0.2333102  0.24871373 0.27056157 0.29382314 0.30587059
#  0.30616824 0.30449373 0.30477647 0.31037961 0.2986149  0.28741569
#  0.26306784 0.23786392 0.23116667 0.23063098 0.22867373 0.2272898
#  0.2699298  0.2699298  0.27637412 0.27637412 0.27637412 0.27359137
#  0.28283333 0.28480549 0.28283333 0.28283333 0.28283333 0.28283333
#  0.28732039 0.28732039 0.29180745 0.29180745 0.28956745 0.29348902
#  0.29377176 0.29377176 0.29153176 0.29153176 0.2898502  0.2898502
#  0.2898502  0.2898502  0.29153176 0.29153176 0.29319843 0.28927686
#  0.28143373 0.28143373 0.27946157 0.28338314 0.28338314 0.27946157
#  0.27946157 0.28143373 0.27976706 0.28173922 0.27976706 0.27192392
#  0.26464627 0.26464627 0.25649765 0.25257608 0.2494651  0.24554353
#  0.24075098 0.23682941 0.23120353 0.22728196 0.2230549  0.21771176
#  0.2185451  0.21600745 0.21375255 0.20983098 0.20926549 0.21318706
#  0.21064941 0.21064941 0.21262157 0.21262157 0.21376039 0.21376039
#  0.21573255 0.21573255 0.21489922 0.21573255 0.21376039 0.21262157
#  0.21262157 0.21262157 0.21262157 0.21262157 0.21376039 0.21376039
#  0.21965412 0.21573255 0.21489922 0.21097765 0.21211647 0.21211647
#  0.21603804 0.21603804 0.2157702  0.21969176 0.22417882 0.22417882
#  0.22307765 0.22307765 0.2250498  0.23094353 0.22338314 0.22171647
#  0.22368863 0.2276102  0.22874902 0.23267059 0.23659216 0.23659216
#  0.23632431 0.24024588 0.24024588 0.24024588 0.24473294 0.25257608
#  0.26826235 0.28394863 0.26602235 0.26602235 0.26069412 0.26069412
#  0.26097686 0.26489843 0.26938549 0.27247373 0.27247373 0.27836745
#  0.27893294 0.28285451 0.28061451 0.28061451 0.28284667 0.28284667
#  0.28538431 0.28538431 0.28930588 0.28930588 0.28763922 0.28763922
#  0.28961137 0.28961137 0.2856898  0.2856898  0.2856898  0.28961137
#  0.28961137 0.29353294 0.29745451 0.29745451 0.30724706 0.30724706
#  0.3122698  0.3122698  0.3122698  0.3122698  0.30637608 0.30328784
#  0.29233373 0.2911949  0.28585176 0.28359686 0.28105922 0.28075373
#  0.27821608 0.28323882 0.27901176 0.27675686 0.27702471 0.27223216
#  0.27109333 0.26743961 0.2682502  0.2682502  0.27243176 0.27243176
#  0.27186627 0.27578784 0.27997725 0.27969451 0.27577294 0.27744745
#  0.27155373 0.27351098 0.27351098 0.27238    0.27404667 0.27348118
#  0.26927686 0.26927686 0.27069843 0.26285529 0.25893373 0.25501216
#  0.25387333 0.2577949  0.26563804 0.26955961 0.26955961 0.26955961]

# %%
fig, axs = plt.subplots(1,N, figsize=(15,5))
i=0
for f in images:
  img = io.imread(f)
  img = color.rgb2gray(img)
  axs[i].imshow(img, vmin=0.0, vmax=0.5, cmap="gray");
  axs[i].set_title(f)
  i = i + 1
plt.show()

# %% [markdown]
# # checking brightness profile for an image

# %%
test = io.imread(images[2])
g = color.rgb2gray(test)
cut = 600          # Cut location
profil = g[cut,:]  # Extract all the pixels of the row 'cut' in the image g
plt.figure(figsize=(10,5))           # New figure with specific display size

plt.subplot(1,2,1)                   # Plot on the left
plt.plot(profil,'b')                 # Brightness profile
plt.title("Brightness profile")      # Title

plt.subplot(1,2,2)                   # Image on the right
plt.imshow(g, cmap="gray")           # Image
plt.plot((0,1919), (cut,cut), 'b')    # Cut line in blue
plt.title("Mandrill")                # Title

plt.show()
