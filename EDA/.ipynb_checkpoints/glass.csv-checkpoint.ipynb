# %% [markdown]
# Adding all libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')
pd.set_option('display.max_columns', 100)

# %% [markdown]
# loading the csv and adding headers from the names file

# %%
h = ['RI: refractive index','Na: Sodium','Mg: Magnesium','Al: Aluminum','Si: Silicon','K: Potassium','Ca: Calcium','Ba: Barium','Fe: Iron','Type of glass']
df=pd.read_csv('data/glass.csv')
#df.to_csv('data/glass.csv',index=False)

# %% [markdown]
# number of rows and columns

# %%
df.shape
# Out:
# (214, 11)

# %% [markdown]
# viewing first 20 rows

# %%
df.head(20)
# Out:
#     RI: refractive index  Na: Sodium  Mg: Magnesium  Al: Aluminum  \
# 0                1.52101       13.64           4.49          1.10
# 1                1.51761       13.89           3.60          1.36
# 2                1.51618       13.53           3.55          1.54
# 3                1.51766       13.21           3.69          1.29
# 4                1.51742       13.27           3.62          1.24
# 5                1.51596       12.79           3.61          1.62
# 6                1.51743       13.30           3.60          1.14
# 7                1.51756       13.15           3.61          1.05
# 8                1.51918       14.04           3.58          1.37
# 9                1.51755       13.00           3.60          1.36
# 10               1.51571       12.72           3.46          1.56
# 11               1.51763       12.80           3.66          1.27
# 12               1.51589       12.88           3.43          1.40
# ...

# %% [markdown]
# getting a description of various data points

# %%
df.describe()
# Out:
#        RI: refractive index  Na: Sodium  Mg: Magnesium  Al: Aluminum  \
# count            214.000000  214.000000     214.000000    214.000000
# mean               1.518365   13.407850       2.684533      1.444907
# std                0.003037    0.816604       1.442408      0.499270
# min                1.511150   10.730000       0.000000      0.290000
# 25%                1.516522   12.907500       2.115000      1.190000
# 50%                1.517680   13.300000       3.480000      1.360000
# 75%                1.519157   13.825000       3.600000      1.630000
# max                1.533930   17.380000       4.490000      3.500000
#
#        Si: Silicon  K: Potassium  Ca: Calcium  Ba: Barium    Fe: Iron  \
# count   214.000000    214.000000   214.000000  214.000000  214.000000
# mean     72.650935      0.497056     8.956963    0.175047    0.057009
# std       0.774546      0.652192     1.423153    0.497219    0.097439
# ...

# %%
glass_type_mapping = {
    1: 'building_windows_float_processed',
    2: 'building_windows_non_float_processed',
    3: 'vehicle_windows_float_processed',
    4: 'vehicle_windows_non_float_processed',
    5: 'containers',
    6: 'tableware',
    7: 'headlamps'
}
df['Glass Type'] = df['Type of glass'].map(glass_type_mapping)
# df.to_csv('data/glass.csv',index=False)
df.head(20)
# Out:
#     RI: refractive index  Na: Sodium  Mg: Magnesium  Al: Aluminum  \
# 0                1.52101       13.64           4.49          1.10
# 1                1.51761       13.89           3.60          1.36
# 2                1.51618       13.53           3.55          1.54
# 3                1.51766       13.21           3.69          1.29
# 4                1.51742       13.27           3.62          1.24
# 5                1.51596       12.79           3.61          1.62
# 6                1.51743       13.30           3.60          1.14
# 7                1.51756       13.15           3.61          1.05
# 8                1.51918       14.04           3.58          1.37
# 9                1.51755       13.00           3.60          1.36
# 10               1.51571       12.72           3.46          1.56
# 11               1.51763       12.80           3.66          1.27
# 12               1.51589       12.88           3.43          1.40
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   RI: refractive index  214 non-null    float64
#  1   Na: Sodium            214 non-null    float64
#  2   Mg: Magnesium         214 non-null    float64
#  3   Al: Aluminum          214 non-null    float64
#  4   Si: Silicon           214 non-null    float64
#  5   K: Potassium          214 non-null    float64
#  6   Ca: Calcium           214 non-null    float64
#  7   Ba: Barium            214 non-null    float64
#  8   Fe: Iron              214 non-null    float64
#  9   Type of glass         214 non-null    int64
#  10  Glass Type            214 non-null    object
# dtypes: float64(9), int64(1), object(1)
# memory usage: 18.5+ KB

# %%
def display_missing(df):    
    for col in df.columns.tolist():          
        print('{} , column missing values: {}'.format(col, df[col].isnull().sum()))
    print('\n')
    
display_missing(df)
# Out:
# RI: refractive index , column missing values: 0
# Na: Sodium , column missing values: 0
# Mg: Magnesium , column missing values: 0
# Al: Aluminum , column missing values: 0
# Si: Silicon , column missing values: 0
# K: Potassium , column missing values: 0
# Ca: Calcium , column missing values: 0
# Ba: Barium , column missing values: 0
# Fe: Iron , column missing values: 0
# Type of glass , column missing values: 0
# Glass Type , column missing values: 0

# %%
ax = df['Type of glass'].value_counts().head(10).plot(kind='bar')
# ax.set_ylabel('count')
# print(df['Glass Type'].value_counts().head(10).plot(kind='bar'))
# print(df[col].head(10))

# %%
for i in range(9):
    result = df.groupby('Glass Type')[df.columns[i]].mean().sort_values(ascending=False)
    print(f'{result}\n')
# Out:
# Glass Type
# containers                              1.518928
# building_windows_float_processed        1.518718
# building_windows_non_float_processed    1.518619
# vehicle_windows_float_processed         1.517964
# tableware                               1.517456
# headlamps                               1.517116
# Name: RI: refractive index, dtype: float64
#
# Glass Type
# tableware                               14.646667
# headlamps                               14.442069
# vehicle_windows_float_processed         13.437059
# building_windows_float_processed        13.242286
# building_windows_non_float_processed    13.111711
# containers                              12.827692
# Name: Na: Sodium, dtype: float64
#
# Glass Type
# building_windows_float_processed        3.552429
# vehicle_windows_float_processed         3.543529
# building_windows_non_float_processed    3.002105
# tableware                               1.305556
# containers                              0.773846
# ...
